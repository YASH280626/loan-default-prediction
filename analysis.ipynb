# %%
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# /Users/shreyanshpathak/Desktop/Python Projects/Loan Default

# %%
df = pd.read_csv('data/Loan_Default.csv')

# %%
df.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#    credit_type  Credit_Score  co-applicant_credit_type    age  \
# ...

# %%
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148670 entries, 0 to 148669
# Data columns (total 34 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   ID                         148670 non-null  int64
#  1   year                       148670 non-null  int64
#  2   loan_limit                 145326 non-null  object
#  3   Gender                     148670 non-null  object
#  4   approv_in_adv              147762 non-null  object
#  5   loan_type                  148670 non-null  object
#  6   loan_purpose               148536 non-null  object
#  7   Credit_Worthiness          148670 non-null  object
#  8   open_credit                148670 non-null  object
#  9   business_or_commercial     148670 non-null  object
#  10  loan_amount                148670 non-null  int64
#  11  rate_of_interest           112231 non-null  float64
#  12  Interest_rate_spread       112031 non-null  float64
# ...

# %%
df['Status']
# Out:
# 0         1
# 1         1
# 2         0
# 3         0
# 4         0
#          ..
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Status, Length: 148670, dtype: int64

# %%
df['dtir1']
# Out:
# 0         45.0
# 1          NaN
# 2         46.0
# 3         42.0
# 4         39.0
#           ...
# 148665    48.0
# 148666    15.0
# 148667    49.0
# 148668    29.0
# 148669    44.0
# Name: dtir1, Length: 148670, dtype: float64

# %%
df['Status'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['ID'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# ID                             int64
# year                           int64
# loan_limit                    object
# Gender                        object
# approv_in_adv                 object
# loan_type                     object
# loan_purpose                  object
# Credit_Worthiness             object
# open_credit                   object
# business_or_commercial        object
# loan_amount                    int64
# rate_of_interest             float64
# Interest_rate_spread         float64
# Upfront_charges              float64
# term                         float64
# Neg_ammortization             object
# interest_only                 object
# lump_sum_payment              object
# property_value               float64
# construction_type             object
# occupancy_type                object
# Secured_by                    object
# total_units                   object
# income                       float64
# credit_type                   object
# ...

# %%
df['year'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['loan_limit'].isnull().sum()
# Out:
# np.int64(3344)

# %%
df['loan_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['approv_in_adv'].isnull().sum()
# Out:
# np.int64(908)

# %%
df['loan_purpose'].isnull().sum()
# Out:
# np.int64(134)

# %%
df['Credit_Worthiness'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['open_credit'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['business_or_commercial'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['loan_amount'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['term'].isnull().sum()
# Out:
# np.int64(41)

# %%
df['Neg_ammortization'].isnull().sum()
# Out:
# np.int64(121)

# %%
df['interest_only'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['lump_sum_payment'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Security_Type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Secured_by'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['construction_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['occupancy_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['total_units'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['total_units'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['submission_of_application'].isnull().sum()
# Out:
# np.int64(200)

# %% [markdown]
# Huge Number of Missing Values

# %%
df['rate_of_interest'].isnull().sum()
# Out:
# np.int64(36439)

# %%
df['Interest_rate_spread'].isnull().sum()
# Out:
# np.int64(36639)

# %%
df['Upfront_charges'].isnull().sum()
# Out:
# np.int64(39642)

# %%
df['dtir1'].isnull().sum()
# Out:
# np.int64(24121)

# %%
df['credit_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Credit_Score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['co-applicant_credit_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['property_value'].isnull().sum()
# Out:
# np.int64(15098)

# %%
df['income'].isnull().sum()
# Out:
# np.int64(9150)

# %%
df['LTV'].isnull().sum()
# Out:
# np.int64(15098)

# %%
duplicates = df[df.duplicated()]
duplicates
# Out:
# Empty DataFrame
# Columns: [ID, year, loan_limit, Gender, approv_in_adv, loan_type, loan_purpose, Credit_Worthiness, open_credit, business_or_commercial, loan_amount, rate_of_interest, Interest_rate_spread, Upfront_charges, term, Neg_ammortization, interest_only, lump_sum_payment, property_value, construction_type, occupancy_type, Secured_by, total_units, income, credit_type, Credit_Score, co-applicant_credit_type, age, submission_of_application, LTV, Region, Security_Type, Status, dtir1]
# Index: []
#
# [0 rows x 34 columns]

# %% [markdown]
# Checking For Duplicate Rows

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Enquiring about Status and its classes (Target Distribution)

# %%
counts = df['Status'].value_counts()

# %%
percentages = df['Status'].value_counts(normalize=True) * 100

# %%
Status_summary = pd.DataFrame({'Counts': counts, 'Percentage (%)' : percentages})
Status_summary
# Out:
#         Counts  Percentage (%)
# Status
# 0       112031       75.355485
# 1        36639       24.644515

# %%
df['rate_of_interest'].count()
# Out:
# np.int64(112231)

# %%
df.describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  148670.000000  148670.0  1.486700e+05     112231.000000
# mean    99224.500000    2019.0  3.311177e+05          4.045476
# std     42917.476598       0.0  1.839093e+05          0.561391
# min     24890.000000    2019.0  1.650000e+04          0.000000
# 25%     62057.250000    2019.0  1.965000e+05          3.625000
# 50%     99224.500000    2019.0  2.965000e+05          3.990000
# 75%    136391.750000    2019.0  4.365000e+05          4.375000
# max    173559.000000    2019.0  3.576500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    109028.000000  148629.000000    1.335720e+05
# mean               0.441656      3224.996127     335.136582    4.978935e+05
# std                0.513043      3251.121510      58.409084    3.599353e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
Q1 =df['loan_amount'].quantile(0.25)
Q3 =df['loan_amount'].quantile(0.75)
IQR = Q3 - Q1
Lower_Bound = Q1 - 1.5*(IQR)
Upper_Bound = Q3 + 1.5*(IQR)

# %%
Upper_Bound
# Out:
# np.float64(796500.0)

# %%
Lower_Bound
# Out:
# np.float64(-163500.0)

# %%
df['loan_amount'].max()
# Out:
# np.int64(3576500)

# %%
above_upper_bound = df[df['loan_amount']>Upper_Bound]

# %%
len(above_upper_bound)
# Out:
# 1895

# %%
percentage_of_loan_amount_outliers = (len(above_upper_bound)/len(df)) * 100

# %%
percentage_of_loan_amount_outliers
# Out:
# 1.2746350978677607

# %%
above_upper_bound.describe()
# Out:
#                   ID    year   loan_amount  rate_of_interest  \
# count    1895.000000  1895.0  1.895000e+03       1047.000000
# mean   100424.435356  2019.0  1.063371e+06          3.930683
# std     43403.047083     0.0  3.060429e+05          0.637248
# min     24934.000000  2019.0  8.065000e+05          2.750000
# 25%     62530.500000  2019.0  8.715000e+05          3.500000
# 50%    100271.000000  2019.0  9.665000e+05          3.875000
# 75%    138242.000000  2019.0  1.141500e+06          4.375000
# max    173468.000000  2019.0  3.576500e+06          6.375000
#
#        Interest_rate_spread  Upfront_charges         term  property_value  \
# count           1046.000000      1023.000000  1895.000000    1.588000e+03
# mean               0.092341      6105.766051   346.904485    1.713567e+06
# std                0.487431      7379.950907    44.790712    9.144523e+05
# min               -1.013200         0.000000   180.000000    6.380000e+05
# ...

# %%
df['income'].describe()
# Out:
# count    139520.000000
# mean       6957.338876
# std        6496.586382
# min           0.000000
# 25%        3720.000000
# 50%        5760.000000
# 75%        8520.000000
# max      578580.000000
# Name: income, dtype: float64

# %%
above_upper_bound['income'].describe()
# Out:
# count      1752.000000
# mean      20690.034247
# std       21181.942678
# min           0.000000
# 25%       12060.000000
# 50%       16320.000000
# 75%       22935.000000
# max      578580.000000
# Name: income, dtype: float64

# %%
df['property_value'].describe()
# Out:
# count    1.335720e+05
# mean     4.978935e+05
# std      3.599353e+05
# min      8.000000e+03
# 25%      2.680000e+05
# 50%      4.180000e+05
# 75%      6.280000e+05
# max      1.650800e+07
# Name: property_value, dtype: float64

# %%
above_upper_bound['property_value'].describe()
# Out:
# count    1.588000e+03
# mean     1.713567e+06
# std      9.144523e+05
# min      6.380000e+05
# 25%      1.208000e+06
# 50%      1.448000e+06
# 75%      1.910500e+06
# max      1.650800e+07
# Name: property_value, dtype: float64

# %%
correlation = df['income'].corr(df['property_value'])
correlation
# Out:
# np.float64(0.4148828378570563)

# %%
correlation = df['loan_amount'].corr(df['property_value'])
correlation
# Out:
# np.float64(0.7342490169595303)

# %%
df[df['Status'] == 0].describe()
# Out:
#                   ID      year   loan_amount  rate_of_interest  \
# count  112031.000000  112031.0  1.120310e+05     112031.000000
# mean    99182.699530    2019.0  3.349908e+05          4.044931
# std     42925.111042       0.0  1.749166e+05          0.561356
# min     24892.000000    2019.0  2.650000e+04          0.000000
# 25%     61964.500000    2019.0  2.065000e+05          3.625000
# 50%     99222.000000    2019.0  3.065000e+05          3.990000
# 75%    136306.000000    2019.0  4.465000e+05          4.375000
# max    173559.000000    2019.0  3.006500e+06          8.000000
#
#        Interest_rate_spread  Upfront_charges           term  property_value  \
# count         112031.000000    108875.000000  112005.000000    1.120290e+05
# mean               0.441656      3227.328554     335.144592    5.056061e+05
# std                0.513043      3251.673989      58.824650    3.427845e+05
# min               -3.638000         0.000000      96.000000    8.000000e+03
# ...

# %%
df[df['Status'] == 1].describe()
# Out:
#                   ID     year   loan_amount  rate_of_interest  \
# count   36639.000000  36639.0  3.663900e+04        200.000000
# mean    99352.313218   2019.0  3.192752e+05          4.350500
# std     42894.457217      0.0  2.085768e+05          0.495546
# min     24890.000000   2019.0  1.650000e+04          3.125000
# 25%     62304.000000   2019.0  1.765000e+05          3.990000
# 50%     99233.000000   2019.0  2.765000e+05          4.312500
# 75%    136669.000000   2019.0  4.165000e+05          4.750000
# max    173553.000000   2019.0  3.576500e+06          5.500000
#
#        Interest_rate_spread  Upfront_charges          term  property_value  \
# count                   0.0       153.000000  36624.000000    2.154300e+04
# mean                    NaN      1565.237974    335.112085    4.577860e+05
# std                     NaN      2299.820513     57.120208    4.362550e+05
# min                     NaN         0.000000     96.000000    8.000000e+03
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['loan_amount'], bins = 10, kde = True)
plt.title("Distribution of Loan Amount")
plt.show()

# %%
sns.histplot(df['income'], bins = 10, kde=True)
plt.title("Distribution of Income")
plt.show()

# %%
sns.histplot(df['Credit_Score'], bins = 10, kde=True)
plt.title("Credit Score Distribution")
plt.show()

# %%
sns.histplot(df['LTV'], bins = 10, kde= True)
plt.title("LTV Distribution")
plt.show()

# %%
df[df['Status'] == 0]['dtir1'].describe()
# Out:
# count    104220.000000
# mean         37.369267
# std          10.027197
# min           5.000000
# 25%          31.000000
# 50%          38.000000
# 75%          44.000000
# max          61.000000
# Name: dtir1, dtype: float64

# %%
df[df['Status'] == 1]['dtir1'].describe()
# Out:
# count    20329.000000
# mean        39.597324
# std         12.716828
# min          5.000000
# 25%         32.000000
# 50%         42.000000
# 75%         49.000000
# max         61.000000
# Name: dtir1, dtype: float64

# %%
sns.histplot(df['dtir1'], bins=10, kde = True)
plt.title("Debt to Income Ratio Distribution")
plt.show()

# %%
sns.boxplot(x='Status', y='LTV', data=df, showfliers=False)
plt.title('LTV by Loan Status')
plt.show()

# %%
sns.boxplot(x='Status', y='dtir1', data=df, showfliers=False)
plt.title("Debt-to-Income Ratio by Loan Status")
plt.show()

# %%
df.select_dtypes(include='object').nunique()
# Out:
# loan_limit                   2
# Gender                       4
# approv_in_adv                2
# loan_type                    3
# loan_purpose                 4
# Credit_Worthiness            2
# open_credit                  2
# business_or_commercial       2
# Neg_ammortization            2
# interest_only                2
# lump_sum_payment             2
# construction_type            2
# occupancy_type               3
# Secured_by                   2
# total_units                  4
# credit_type                  4
# co-applicant_credit_type     2
# age                          7
# submission_of_application    2
# Region                       4
# Security_Type                2
# dtype: int64

# %%
loan_type_status = pd.crosstab(df['loan_type'], df['Status'], normalize='index')*100
loan_type_status
# Out:
# Status             0          1
# loan_type
# type1      77.225133  22.774867
# type2      65.456122  34.543878
# type3      74.944011  25.055989

# %%
loan_limit_status = pd.crosstab(df['loan_limit'], df['Status'], normalize='index')*100
loan_limit_status
# Out:
# Status              0          1
# loan_limit
# cf          76.029199  23.970801
# ncf         66.786931  33.213069

# %%
loan_purpose_status = pd.crosstab(df['loan_purpose'], df['Status'], normalize='index')*100
loan_purpose_status
# Out:
# Status                0          1
# loan_purpose
# p1            74.123201  25.876799
# p2            66.921197  33.078803
# p3            74.977652  25.022348
# p4            77.025128  22.974872

# %%
credit_worthiness_status = pd.crosstab(df['Credit_Worthiness'], df['Status'], normalize='index')*100
credit_worthiness_status
# Out:
# Status                     0          1
# Credit_Worthiness
# l1                 75.672315  24.327685
# l2                 68.226367  31.773633

# %%
open_credit_status = pd.crosstab(df['open_credit'],df['Status'], normalize='index')*100
open_credit_status
# Out:
# Status               0          1
# open_credit
# nopc         75.329138  24.670862
# opc          82.374101  17.625899

# %%
business_or_commercial_status = pd.crosstab(df['business_or_commercial'], df['Status'], normalize='index')*100
business_or_commercial_status
# Out:
# Status                          0          1
# business_or_commercial
# b/c                     65.456122  34.543878
# nob/c                   76.962348  23.037652

# %%
negative_ammortization_status = pd.crosstab(df['Neg_ammortization'], df['Status'], normalize='index')*100
negative_ammortization_status
# Out:
# Status                     0          1
# Neg_ammortization
# neg_amm            55.403530  44.596470
# not_neg            77.619547  22.380453

# %%
df['Neg_ammortization'].value_counts(normalize=True)*100
# Out:
# Neg_ammortization
# not_neg    89.815482
# neg_amm    10.184518
# Name: proportion, dtype: float64

# %%
interest_only_status = pd.crosstab(df['interest_only'], df['Status'], normalize='index')*100
interest_only_status
# Out:
# Status                 0          1
# interest_only
# int_only       72.686357  27.313643
# not_int        75.489545  24.510455

# %%
lump_sum_payment_status = pd.crosstab(df['lump_sum_payment'], df['Status'], normalize='index')*100
lump_sum_payment_status
# Out:
# Status                    0          1
# lump_sum_payment
# lpsm              22.340426  77.659574
# not_lpsm          76.590312  23.409688

# %%
df['lump_sum_payment'].value_counts(normalize=True)*100
# Out:
# lump_sum_payment
# not_lpsm    97.723818
# lpsm         2.276182
# Name: proportion, dtype: float64

# %%
construction_type_status = pd.crosstab(df['construction_type'], df['Status'], normalize='index')*100
construction_type_status
# Out:
# Status                     0           1
# construction_type
# mh                  0.000000  100.000000
# sb                 75.372216   24.627784

# %%
occupancy_type_status = pd.crosstab(df['occupancy_type'], df['Status'], normalize = 'index')*100
occupancy_type_status
# Out:
# Status                  0          1
# occupancy_type
# ir              70.013624  29.986376
# pr              75.695545  24.304455
# sr              72.866731  27.133269

# %%
secured_by_status = pd.crosstab(df['Secured_by'], df['Status'], normalize='index')*100
secured_by_status
# Out:
# Status              0           1
# Secured_by
# home        75.372216   24.627784
# land         0.000000  100.000000

# %%
df['Secured_by'].value_counts(normalize=True)*100
# Out:
# Secured_by
# home    99.977803
# land     0.022197
# Name: proportion, dtype: float64

# %%
total_units_status = pd.crosstab(df['total_units'], df['Status'], normalize='index')*100
total_units_status
# Out:
# Status               0          1
# total_units
# 1U           75.503140  24.496860
# 2U           65.470548  34.529452
# 3U           61.577608  38.422392
# 4U           70.312500  29.687500

# %%
credit_type_status = pd.crosstab(df['credit_type'], df['Status'], normalize='index')*100
credit_type_status
# Out:
# Status               0          1
# credit_type
# CIB          84.195880  15.804120
# CRIF         83.765746  16.234254
# EQUI          0.006537  99.993463
# EXP          84.014618  15.985382

# %%
df['credit_type'].value_counts(normalize=True)*100
# Out:
# credit_type
# CIB     32.388511
# CRIF    29.529159
# EXP     27.792426
# EQUI    10.289904
# Name: proportion, dtype: float64

# %%
co_applicant_credit_type_status = pd.crosstab(df['co-applicant_credit_type'], df['Status'], normalize='index')*100
co_applicant_credit_type_status
# Out:
# Status                            0          1
# co-applicant_credit_type
# CIB                       81.566566  18.433434
# EXP                       69.134872  30.865128

# %%
df['co-applicant_credit_type'].value_counts(normalize=True)*100
# Out:
# co-applicant_credit_type
# CIB    50.03834
# EXP    49.96166
# Name: proportion, dtype: float64

# %%
age_status = pd.crosstab(df['age'], df['Status'], normalize='index')*100
age_status
# Out:
# Status          0          1
# age
# 25-34   77.807962  22.192038
# 35-44   77.728685  22.271315
# 45-54   75.953341  24.046659
# 55-64   74.113235  25.886765
# 65-74   73.144042  26.855958
# <25     71.054600  28.945400
# >74     69.993031  30.006969

# %%
submission_of_application_status = pd.crosstab(df['submission_of_application'], df['Status'], normalize='index')*100
submission_of_application_status
# Out:
# Status                             0          1
# submission_of_application
# not_inst                   82.478730  17.521270
# to_inst                    71.598096  28.401904

# %%
df['submission_of_application'].value_counts(normalize=True)*100
# Out:
# submission_of_application
# to_inst     64.534249
# not_inst    35.465751
# Name: proportion, dtype: float64

# %%
security_type_status = pd.crosstab(df['Security_Type'], df['Status'], normalize='index')*100
security_type_status
# Out:
# Status                 0           1
# Security_Type
# Indriect        0.000000  100.000000
# direct         75.372216   24.627784

# %%
df['Security_Type'].value_counts(normalize=True)*100
# Out:
# Security_Type
# direct      99.977803
# Indriect     0.022197
# Name: proportion, dtype: float64

# %%
region_status = pd.crosstab(df['Region'], df['Status'], normalize='index')*100
region_status
# Out:
# Status              0          1
# Region
# North       77.488558  22.511442
# North-East  69.554656  30.445344
# central     72.461768  27.538232
# south       73.370720  26.629280

# %%
df['Region'].value_counts(normalize=True)*100
# Out:
# Region
# North         50.260308
# south         43.059124
# central        5.849869
# North-East     0.830699
# Name: proportion, dtype: float64

# %%
df.select_dtypes(include='int64').columns.tolist()
# Out:
# ['ID', 'year', 'loan_amount', 'Credit_Score', 'Status']

# %%
df.select_dtypes(include='float64').columns.tolist()
# Out:
# ['rate_of_interest',
#  'Interest_rate_spread',
#  'Upfront_charges',
#  'term',
#  'property_value',
#  'income',
#  'LTV',
#  'dtir1']

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Status', axis=1)
y = df['Status']

# %%
X.head()
# Out:
#       ID  year loan_limit             Gender approv_in_adv loan_type  \
# 0  24890  2019         cf  Sex Not Available         nopre     type1
# 1  24891  2019         cf               Male         nopre     type2
# 2  24892  2019         cf               Male           pre     type1
# 3  24893  2019         cf               Male         nopre     type1
# 4  24894  2019         cf              Joint           pre     type1
#
#   loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 0           p1                l1        nopc                  nob/c  ...
# 1           p1                l1        nopc                    b/c  ...
# 2           p1                l1        nopc                  nob/c  ...
# 3           p4                l1        nopc                  nob/c  ...
# 4           p1                l1        nopc                  nob/c  ...
#
#     income  credit_type  Credit_Score  co-applicant_credit_type    age  \
# ...

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    0
# 4    0
# Name: Status, dtype: int64

# %%
y.tail()
# Out:
# 148665    0
# 148666    0
# 148667    0
# 148668    0
# 148669    0
# Name: Status, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state = 34)

# %%
X_train.head()
# Out:
#             ID  year loan_limit             Gender approv_in_adv loan_type  \
# 9415     34305  2019         cf              Joint         nopre     type2
# 144091  168981  2019         cf  Sex Not Available         nopre     type2
# 92471   117361  2019         cf               Male         nopre     type3
# 77613   102503  2019         cf              Joint         nopre     type1
# 90092   114982  2019         cf               Male           pre     type1
#
#        loan_purpose Credit_Worthiness open_credit business_or_commercial  ...  \
# 9415             p1                l1        nopc                    b/c  ...
# 144091           p1                l1        nopc                    b/c  ...
# 92471            p3                l1        nopc                  nob/c  ...
# 77613            p3                l1        nopc                  nob/c  ...
# 90092            p1                l1        nopc                  nob/c  ...
#
# ...

# %%
X_train.shape
# Out:
# (118936, 33)

# %%
X_train['ID'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['year'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['loan_limit'].isnull().sum()
# Out:
# np.int64(2701)

# %%
X_train['loan_limit'].mode()
# Out:
# 0    cf
# Name: loan_limit, dtype: object

# %%
X_train['loan_limit'].value_counts(normalize=True)*100
# Out:
# loan_limit
# cf     93.101045
# ncf     6.898955
# Name: proportion, dtype: float64

# %% [markdown]
# Mode is the dominant category in the dataset so for missing values we will create a new category "Unknown"

# %%
y_train.value_counts(normalize=True)*100
# Out:
# Status
# 0    75.398534
# 1    24.601466
# Name: proportion, dtype: float64

# %%
X_train['loan_limit'] = X_train['loan_limit'].fillna('Unknown')

# %%
X_test['loan_limit'] = X_test['loan_limit'].fillna('Unknown')

# %%
X_train['Gender'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['approv_in_adv'].isnull().sum()
# Out:
# np.int64(725)

# %%
X_train['approv_in_adv'].mode()
# Out:
# 0    nopre
# Name: approv_in_adv, dtype: object

# %%
X_train['approv_in_adv'].value_counts(normalize=True)*100
# Out:
# approv_in_adv
# nopre    84.34748
# pre      15.65252
# Name: proportion, dtype: float64

# %%
X_train['approv_in_adv'] = X_train['approv_in_adv'].fillna('Unknown')

# %%
X_test['approv_in_adv'] = X_test['approv_in_adv'].fillna('Unknown')

# %%
X_train['loan_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['loan_limit'].value_counts(normalize=True)*100
# Out:
# loan_limit
# cf         90.986749
# ncf         6.742282
# Unknown     2.270969
# Name: proportion, dtype: float64

# %%
X_train['loan_purpose'].value_counts(normalize=True)*100
# Out:
# loan_purpose
# p3    37.733007
# p4    36.829172
# p1    23.220312
# p2     2.217509
# Name: proportion, dtype: float64

# %%
X_train['loan_purpose'].isnull().sum()
# Out:
# np.int64(109)

# %%
most_frequent_cat = X_train['loan_purpose'].mode()[0]

# %%
X_train['loan_purpose'] = X_train['loan_purpose'].fillna(most_frequent_cat)

# %%
X_test['loan_purpose'] = X_test['loan_purpose'].fillna(most_frequent_cat)

# %%
X_train['Credit_Worthiness'].value_counts(normalize=True)*100
# Out:
# Credit_Worthiness
# l1    95.730477
# l2     4.269523
# Name: proportion, dtype: float64

# %%
X_train['Credit_Worthiness'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['open_credit'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['business_or_commercial'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train.select_dtypes(include='object').nunique()
# Out:
# loan_limit                   3
# Gender                       4
# approv_in_adv                3
# loan_type                    3
# loan_purpose                 4
# Credit_Worthiness            2
# open_credit                  2
# business_or_commercial       2
# Neg_ammortization            2
# interest_only                2
# lump_sum_payment             2
# construction_type            2
# occupancy_type               3
# Secured_by                   2
# total_units                  4
# credit_type                  4
# co-applicant_credit_type     2
# age                          7
# submission_of_application    2
# Region                       4
# Security_Type                2
# dtype: int64

# %%
X_train['Neg_ammortization'].isnull().sum()
# Out:
# np.int64(93)

# %%
X_train['Neg_ammortization'].value_counts(normalize=True)*100
# Out:
# Neg_ammortization
# not_neg    89.854682
# neg_amm    10.145318
# Name: proportion, dtype: float64

# %%
X_train['Neg_ammortization'] = X_train['Neg_ammortization'].fillna('Unknown')

# %%
X_test['Neg_ammortization'] = X_test['Neg_ammortization'].fillna('Unknown')

# %%
X_train['interest_only'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['lump_sum_payment'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['construction_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['occupancy_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['Secured_by'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['total_units'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['credit_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['co-applicant_credit_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['age'].isnull().sum()
# Out:
# np.int64(166)

# %%
X_train['age'].value_counts(normalize=True)*100
# Out:
# age
# 45-54    23.376273
# 35-44    22.060285
# 55-64    21.896944
# 65-74    14.032163
# 25-34    12.870253
# >74       4.842974
# <25       0.921108
# Name: proportion, dtype: float64

# %%
X_train['age'] = X_train['age'].fillna('Unknown')

# %%
X_test['age'] = X_test['age'].fillna('Unknown')

# %%
X_train['submission_of_application'].isnull().sum()
# Out:
# np.int64(166)

# %%
X_train['submission_of_application'].value_counts(normalize=True)*100
# Out:
# submission_of_application
# to_inst     64.567652
# not_inst    35.432348
# Name: proportion, dtype: float64

# %%
most_frequent_cat_sob = X_train['submission_of_application'].mode()[0]

# %%
X_train['submission_of_application'] = X_train['submission_of_application'].fillna(most_frequent_cat_sob)

# %%
X_test['submission_of_application'] = X_test['submission_of_application'].fillna(most_frequent_cat_sob)

# %%
X_train['Region'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['Security_Type'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train.select_dtypes(include='float64').columns.tolist()
# Out:
# ['rate_of_interest',
#  'Interest_rate_spread',
#  'Upfront_charges',
#  'term',
#  'property_value',
#  'income',
#  'LTV',
#  'dtir1']

# %%
X_train.select_dtypes(include='int64').columns.tolist()
# Out:
# ['ID', 'year', 'loan_amount', 'Credit_Score']

# %%
X_train['loan_amount'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['Credit_Score'].isnull().sum()
# Out:
# np.int64(0)

# %%
X_train['rate_of_interest'].isnull().sum()
# Out:
# np.int64(29094)

# %%
Q1 = X_train['rate_of_interest'].quantile(0.25)
Q1
# Out:
# np.float64(3.625)

# %%
Q3 = X_train['rate_of_interest'].quantile(0.75)
Q3
# Out:
# np.float64(4.375)

# %%
IQR_rate_of_interest = Q3 - Q1
IQR_rate_of_interest
# Out:
# np.float64(0.75)

# %%
lower_bound_rate_of_interest = Q1 - 1.5*(IQR_rate_of_interest)
lower_bound_rate_of_interest
# Out:
# np.float64(2.5)

# %%
upper_bound_rate_of_interest = Q3 + 1.5*(IQR_rate_of_interest)
upper_bound_rate_of_interest
# Out:
# np.float64(5.5)

# %%
sns.boxplot(X_train['rate_of_interest'])
# Out:
# <Axes: ylabel='rate_of_interest'>

# %%
rate_of_interest_median = X_train['rate_of_interest'].median()

# %%
X_train['rate_of_interest'] = X_train['rate_of_interest'].fillna(rate_of_interest_median)

# %%
X_test['rate_of_interest'] = X_test['rate_of_interest'].fillna(rate_of_interest_median)

# %%
X_train['Interest_rate_spread'].isnull().sum()
# Out:
# np.int64(29260)

# %%
X_train['Interest_rate_spread'].describe()
# Out:
# count    89676.000000
# mean         0.442851
# std          0.512815
# min         -3.638000
# 25%          0.077100
# 50%          0.391600
# 75%          0.778325
# max          3.357000
# Name: Interest_rate_spread, dtype: float64

# %%
sns.boxplot(data=X_train['Interest_rate_spread'])
# Out:
# <Axes: ylabel='Interest_rate_spread'>

# %%
interest_rate_spread_median = X_train['Interest_rate_spread'].median()
X_train['Interest_rate_spread'] = X_train['Interest_rate_spread'].fillna(interest_rate_spread_median)

# %%
X_test['Interest_rate_spread'] = X_test['Interest_rate_spread'].fillna(interest_rate_spread_median)

# %%
X_train['Upfront_charges'].isnull().sum()
# Out:
# np.int64(31683)

# %%
X_train['Upfront_charges'].describe()
# Out:
# count    87253.000000
# mean      3227.007324
# std       3250.396641
# min          0.000000
# 25%        589.500000
# 50%       2598.750000
# 75%       4813.850000
# max      60000.000000
# Name: Upfront_charges, dtype: float64

# %%
sns.boxplot(data=X_train['Upfront_charges'])
# Out:
# <Axes: ylabel='Upfront_charges'>

# %%
upfront_charges_median = X_train['Upfront_charges'].median()

# %%
X_train['Upfront_charges'] = X_train['Upfront_charges'].fillna(upfront_charges_median)

# %%
X_test['Upfront_charges'] = X_test['Upfront_charges'].fillna(upfront_charges_median)

# %%
X_train['term'].isnull().sum()
# Out:
# np.int64(30)

# %%
X_train['term'].describe()
# Out:
# count    118906.000000
# mean        335.107673
# std          58.466627
# min          96.000000
# 25%         360.000000
# 50%         360.000000
# 75%         360.000000
# max         360.000000
# Name: term, dtype: float64

# %%
sns.boxplot(data=X_train['term'])
# Out:
# <Axes: ylabel='term'>

# %%
X_train['term'].value_counts(normalize=True)*100
# Out:
# term
# 360.0    0.818697
# 180.0    0.087708
# 240.0    0.039165
# 324.0    0.018729
# 300.0    0.018653
# 120.0    0.003473
# 144.0    0.001842
# 348.0    0.001766
# 336.0    0.001455
# 312.0    0.001287
# 96.0     0.001262
# 156.0    0.001203
# 216.0    0.000748
# 288.0    0.000664
# 276.0    0.000648
# 132.0    0.000614
# 168.0    0.000597
# 228.0    0.000463
# 204.0    0.000370
# 264.0    0.000278
# 108.0    0.000177
# 192.0    0.000118
# 252.0    0.000067
# 280.0    0.000008
# 165.0    0.000008
# Name: proportion, dtype: float64

# %%
sns.countplot(data=X_train, x = 'term')
# Out:
# <Axes: xlabel='term', ylabel='count'>

# %%
term_mode = X_train['term'].mode()[0]
X_train['term'] = X_train['term'].fillna(term_mode)

# %%
X_test['term'] = X_test['term'].fillna(term_mode)

# %%
X_train['property_value'].isnull().sum()
# Out:
# np.int64(12111)

# %%
sns.boxplot(data=X_train['property_value'])
# Out:
# <Axes: ylabel='property_value'>

# %%
property_value_median = X_train['property_value'].median()

# %%
X_train['property_value'] = X_train['property_value'].fillna(property_value_median)

# %%
X_test['property_value'] = X_test['property_value'].fillna(property_value_median)

# %%
X_train['income'].isnull().sum()
# Out:
# np.int64(7281)

# %%
sns.boxplot(data=X_train['income'])
# Out:
# <Axes: ylabel='income'>

# %%
income_median = X_train['income'].median()

# %%
X_train['income'] = X_train['income'].fillna(income_median)

# %%
X_test['income'] = X_test['income'].fillna(income_median)

# %%
X_train['LTV'].isnull().sum()
# Out:
# np.int64(12111)

# %%
sns.boxplot(data=X_train['LTV'])
# Out:
# <Axes: ylabel='LTV'>

# %%
LTV_median = X_train['LTV'].median()

# %%
X_train['LTV'] = X_train['LTV'].fillna(LTV_median)

# %%
X_test['LTV'] = X_test['LTV'].fillna(LTV_median)
